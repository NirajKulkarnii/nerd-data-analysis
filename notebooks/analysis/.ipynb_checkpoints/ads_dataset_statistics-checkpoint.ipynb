# %%
# Import necessary libraries
import pandas as pd  # For data manipulation and analysis
import numpy as np  # For numerical operations
from collections import Counter  # For counting hashable objects
import matplotlib.pyplot as plt  # For plotting
import seaborn as sns  # For advanced data visualization
from urllib.parse import urlparse  # For parsing URLs

# Ensure plots are displayed in the notebook (if applicable)
plt.style.use('seaborn')  # Use seaborn style for matplotlib

# %%
# Import the necessary module to mount Google Drive in Google Colab
from google.colab import drive

# Mount Google Drive to access files stored in it
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define file paths for datasets related to Luis and Niraj
datapath_luis_articles = (
    '/content/drive/MyDrive/Cardiff/Grants/NERD: '
    'Neutralizing Economic Rewards of Disinformation/Result_artifacts/Articles_Data_Archive/combined_articles_dataset.csv'
)

datapath_luis_ads = (
    '/content/drive/MyDrive/Cardiff/Grants/NERD: '
    'Neutralizing Economic Rewards of Disinformation/Result_artifacts/Ads_Data_Archive/combined_ads_dataset.csv'
)

datapath_niraj_articles = (
    '/content/drive/MyDrive/NERD: '
    'Neutralizing Economic Rewards of Disinformation/Result_artifacts/Articles_Data_Archive/combined_articles_dataset.csv'
)

datapath_niraj_ads = (
    '/content/drive/MyDrive/NERD: '
    'Neutralizing Economic Rewards of Disinformation/Result_artifacts/Ads_Data_Archive/combined_ads_dataset.csv'
)

datapath_niraj_map = (
    '/content/drive/MyDrive/NERD: '
    'Neutralizing Economic Rewards of Disinformation/1 - Data collection/folder_number_to_source_url_mapping.csv'
)

datapath_niraj_original_file1 = (
    '/content/drive/MyDrive/NERD: '
    'Neutralizing Economic Rewards of Disinformation/1 - Data collection/ee24_simple.csv'
)

datapath_niraj_original_file2 = (
    '/content/drive/MyDrive/NERD: '
    'Neutralizing Economic Rewards of Disinformation/1 - Data collection/ee24_simple-with-dates-2024-07-09.csv'
)

# Load dataframes for ads and articles datasets
ads_df = pd.read_csv(datapath_niraj_ads)
article_df = pd.read_csv(datapath_niraj_articles)

# Uncomment these lines to load additional original files if needed
# original_df1 = pd.read_csv(datapath_niraj_original_file1)
# original_df2 = pd.read_csv(datapath_niraj_original_file2)

# Uncomment this line to load the folder-to-url mapping file
# folder_url_map_df = pd.read_csv(datapath_niraj_map)

# %%
# Convert string representation of lists in 'Image_Links' to actual lists
article_df['Image_Links'] = article_df['Image_Links'].apply(ast.literal_eval)

# Calculate the number of images per article and create a new column
article_df['Num_of_screen'] = article_df['Image_Links'].apply(len)

# Calculate the total number of screenshots across all articles
screenshot_num = article_df['Num_of_screen'].sum()

# %% [markdown]
# ## Basic Statistics for Advertisement Data
#
# This code calculates key statistics for the advertisement dataset, providing insights into ad distribution, product representation, company diversity, and text length characteristics.

# %%
  # Basic Statistics

  # Total number of ads
  total_ads = len(ads_df)

  # Count unique products, excluding NA entries
  unique_products = ads_df['Product'].dropna().nunique()

  # Count unique companies, excluding NA entries
  unique_companies = ads_df['Company'].dropna().nunique()

  # Distribution of ad placements
  ad_placement_distribution = ads_df['Ad_Placement'].value_counts()

  # Calculate ad name length statistics
  ad_name_length = ads_df['Ad_Name'].str.len()
  average_ad_name_length = ad_name_length.mean()
  median_ad_name_length = ad_name_length.median()
  max_ad_name_length = ad_name_length.max()

  # Calculate ad description length statistics
  ad_description_length = ads_df['Ad_Description'].str.len()
  average_description_length = ad_description_length.mean()
  median_description_length = ad_description_length.median()
  max_description_length = ad_description_length.max()

  # Get the top 20 products by count
  product_distribution = ads_df['Product'].dropna().value_counts().head(20)

  # Get the top 20 companies, excluding 'Unknown' and 'Not specified'
  company_representation = ads_df['Company'].dropna().value_counts()
  company_representation = company_representation[~company_representation.index.isin(['Unknown', 'Not specified'])]
  company_representation = company_representation.head(20)

# %%
# Summary of the statistics

# Create a dictionary to store the statistics
statistics = {
    'Total Number of ScreenShots': [screenshot_num],  # Assuming screenshot_num is defined elsewhere
    'Total Number of Ads': [total_ads],
    'Unique Products': [unique_products],
    'Unique Companies': [unique_companies],
    'Average Ad Name Length': [average_ad_name_length],
    'Median Ad Name Length': [median_ad_name_length],
    'Max Ad Name Length': [max_ad_name_length],
    'Average Ad Description Length':[ average_description_length],
    'Median Ad Description Length': [median_description_length],
    'Max Ad Description Length': [max_description_length],
}
pd.DataFrame(statistics)
# Out:
#    Total Number of ScreenShots  Total Number of Ads  Unique Products  \
# 0                         1326                 1849             1206
#
#    Unique Companies  Average Ad Name Length  Median Ad Name Length  \
# 0               635               17.927123                   16.0
#
#    Max Ad Name Length  Average Ad Description Length  \
# 0                80.0                      62.960305
#
#    Median Ad Description Length  Max Ad Description Length
# 0                          60.0                      199.0

# %% [markdown]
# ## Visualizing Product Distribution
#
# This code snippet creates a bar chart to display the distribution of the top 20 products based on their frequency in the advertisement dataset.

# %%
# Plot the product distribution
plt.figure(figsize=(8, 6))
product_distribution.plot(kind='bar', color='skyblue')

# Add labels and title for the product distribution plot
plt.xlabel('Products')
plt.ylabel('Frequency')
plt.title('Top 20 Products')
plt.xticks(rotation=45, ha='right')  # Rotate the x labels for better readability
plt.tight_layout()  # Adjust layout to prevent label cut-off
plt.savefig('Top 20 products.png')
# Show the product distribution plot
plt.show()

# %% [markdown]
# ## Visualizing Company Representation
#
# This code snippet creates a bar chart to showcase the distribution of the top 20 companies based on their frequency in the advertisement dataset.

# %%
# Plot the company representation
plt.figure(figsize=(8, 6))
company_representation.plot(kind='bar', color='skyblue')

# Add labels and title for the company representation plot
plt.xlabel('Companies')
plt.ylabel('Frequency')
plt.title('Top 20 Companies')
plt.xticks(rotation=45, ha='right')  # Rotate the x labels for better readability
plt.tight_layout()  # Adjust layout to prevent label cut-off
plt.savefig('Top_20_company.png')
# Show the company representation plot
plt.show()

# %% [markdown]
# # Visualizing Ad Distribution by Sector
#
# This code snippet generates a pie chart showing the distribution of advertisements across the top 20 sectors based on their frequency in the advertisement dataset.

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

tokenizer = AutoTokenizer.from_pretrained("cardiffnlp/twitter-roberta-large-topic-latest")
model = AutoModelForSequenceClassification.from_pretrained("cardiffnlp/twitter-roberta-large-topic-latest")
def generate_prompt(ad_name,product,company,ad_description):
    return  f" Ad Name: {ad_name}\nProduct: {product}\n Company: {company}\n Ad Description: {ad_description}"

pipe = pipeline('text-classification', model="cardiffnlp/twitter-roberta-large-topic-latest", return_all_scores=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.90k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:106: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(

# %%
from tqdm import tqdm

# %%
# ads_df.head()

# %%
"""tags = []
for ad_name, product, company, ad_description in tqdm(zip(ads_df['Ad_Name'],ads_df['Product'],ads_df['Company'],ads_df['Ad_Description'])):
    prompt = generate_prompt(ad_name,product,company,ad_description)
    predictions=pipe(prompt)[0]
    pred = max(predictions,key=lambda x:x['score'])
    tags.append(pred)

"""
# Out:
# 718it [08:48,  1.36it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-410fa247df82> in <cell line: 2>()
#       2 for ad_name, product, company, ad_description in tqdm(zip(ads_df['Ad_Name'],ads_df['Product'],ads_df['Company'],ads_df['Ad_Description'])):
#       3     prompt = generate_prompt(ad_name,product,company,ad_description)
# ----> 4     predictions=pipe(prompt)[0]
#       5     pred = max(predictions,key=lambda x:x['score'])
#       6     tags.append(pred)
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py in __call__(self, inputs, **kwargs)
#     157         """
#     158         inputs = (inputs,)
# --> 159         result = super().__call__(*inputs, **kwargs)
#     160         # TODO try and retrieve it in a nicer way from _sanitize_parameters.
#     161         _legacy = "top_k" not in kwargs
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1300             )
#    1301         else:
# -> 1302             return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#    1303
#    1304     def run_multi(self, inputs, preprocess_params, forward_params, postprocess_params):
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1307     def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1308         model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1309         model_outputs = self.forward(model_inputs, **forward_params)
#    1310         outputs = self.postprocess(model_outputs, **postprocess_params)
#    1311         return outputs
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1207                 with inference_context():
#    1208                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1209                     model_outputs = self._forward(model_inputs, **forward_params)
#    1210                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1211             else:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py in _forward(self, model_inputs)
#     188         if "use_cache" in inspect.signature(model_forward).parameters.keys():
#     189             model_inputs["use_cache"] = False
# --> 190         return self.model(**model_inputs)
#     191
#     192     def postprocess(self, model_outputs, function_to_apply=None, top_k=1, _legacy=True):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1316         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1317
# -> 1318         outputs = self.roberta(
#    1319             input_ids,
#    1320             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     974         head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     975
# --> 976         encoder_outputs = self.encoder(
#     977             embedding_output,
#     978             attention_mask=extended_attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     629                 )
#     630             else:
# --> 631                 layer_outputs = layer_module(
#     632                     hidden_states,
#     633                     attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     518         # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     519         self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 520         self_attention_outputs = self.attention(
#     521             hidden_states,
#     522             attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     445         output_attentions: Optional[bool] = False,
#     446     ) -> Tuple[torch.Tensor]:
# --> 447         self_outputs = self.self(
#     448             hidden_states,
#     449             attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     323         bsz, tgt_len, _ = hidden_states.size()
#     324
# --> 325         query_layer = self.transpose_for_scores(self.query(hidden_states))
#     326
#     327         # If this is instantiated as a cross-attention module, the keys and values come from an encoder; the attention
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     123
#     124     def forward(self, input: Tensor) -> Tensor:
# --> 125         return F.linear(input, self.weight, self.bias)
#     126
#     127     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
"""
sector_list = [tag['label'] for tag in tags]

# Count occurrences of each sector
sector_counts = Counter(sector_list)
# Get the top 20 sectors
top_10_sectors = sector_counts.most_common(10)

# Separate sector names and their counts
sectors, ad_counts = zip(*top_10_sectors)

# Create a pie chart
plt.figure(figsize=(8,8))
plt.pie(ad_counts, labels=sectors, autopct='%1.1f%%', startangle=90)
plt.title('Top 10 Sectors - Ad Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()"""

# %%
def merge_ad_article_data(ads_df: pd.DataFrame, articles_df: pd.DataFrame) -> pd.DataFrame:
    """
    Merge ads and articles datasets based on matching image URLs.

    Parameters:
    -----------
    ads_df : DataFrame
        Dataset containing ad information with 'Image_Link' column
    articles_df : DataFrame
        Dataset containing article information with 'Image_Links' column (array/list)

    Returns:
    --------
    DataFrame
        Enhanced ads dataset with article metadata for each ad
    """
    # Create a mapping of image URLs to article metadata
    image_to_article = {}
    for _, article in articles_df.iterrows():
        # Convert string representation of list to actual list if needed
        if isinstance(article['Image_Links'], str):
            image_links = eval(article['Image_Links'])
        else:
            image_links = article['Image_Links']

        # Add article metadata for each image
        for img_url in image_links:
            image_to_article[img_url] = {
                'Published_Date': article['Published_Date'],
                'Sentiment': article['Sentiment'],
                'Tone': article['Tone'],
                'Article_Text': article['Article_Text'],
                'Headline': article['Headline'],
                'Publishing_Agency_Name': article['Publishing_Agency_Name'],
                'Keywords_Tags': article['Keywords_Tags'],
                'Related_Article_Links': article['Related_Article_Links'],
                'Narrative': article['Narrative']
                # Add any other article metadata you need
            }

    # Add article metadata to ads based on matching image URLs
    enhanced_ads = []
    unmatched_ads = []

    for _, ad in ads_df.iterrows():
        ad_data = ad.to_dict()
        if ad['Image_Link'] in image_to_article:
            ad_data.update(image_to_article[ad['Image_Link']])
            enhanced_ads.append(ad_data)
        else:
            unmatched_ads.append(ad['Image_Link'])

    # Create merged dataframe
    merged_df = pd.DataFrame(enhanced_ads)

    # Preprocess dates
    merged_df['Published_Date'] = pd.to_datetime(
        merged_df['Published_Date'],
        format='%d-%m-%Y',
        errors='coerce'
    )

    # Add derived date features
    merged_df['Month'] = merged_df['Published_Date'].dt.month
    merged_df['Month_Name'] = merged_df['Published_Date'].dt.month_name()
    merged_df['Weekday'] = merged_df['Published_Date'].dt.day_name()

    # Print matching statistics
    print(f"Total ads: {len(ads_df)}")
    print(f"Successfully matched ads: {len(enhanced_ads)}")
    print(f"Unmatched ads: {len(unmatched_ads)}")
    if unmatched_ads:
        print("\nSample of unmatched ad images:")
        for url in unmatched_ads[:5]:
            print(f"- {url}")

    return merged_df

# %% [markdown]
# ### Heatmap for company/products vs Media House

# %%
#combined_original_df = pd.concat([original_df1,original_df2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-500d37dc713b> in <cell line: 1>()
# ----> 1 combined_original_df = pd.concat([original_df1,original_df2])
#
# NameError: name 'original_df1' is not defined

# %%
#mdf = merge_ad_article_data(ads_df,article_df)

# %%
"""
# Clean 'ID' column in merged_data to remove '#' character if the value is a string
folder_url_map_df['ID'] = folder_url_map_df['ID'].apply(lambda x: str(x).replace('#', '') if isinstance(x, str) else x)

# Merge the 'mdf' dataframe with 'folder_url_map_df' based on 'Folder_Number' and 'ID' columns
mdf = mdf.merge(folder_url_map_df, left_on='Folder_Number', right_on='ID', how='left')

# Drop 'ID' and 'Observations' columns from the 'mdf' dataframe as they are no longer needed
mdf = mdf.drop(columns=['ID', 'Observations'])

# Filter rows with non-null 'Links' column values
filtered_mdf = mdf.dropna(subset=['Links'])

# Merge 'filtered_mdf' with 'combined_original_df' dataframe based on the 'Links' and 'source_url' columns
merged_data_with_org = filtered_mdf.merge(combined_original_df, left_on='Links', right_on='source_url', how='left')
"""
# Out:
# "\n# Clean 'ID' column in merged_data to remove '#' character if the value is a string\nfolder_url_map_df['ID'] = folder_url_map_df['ID'].apply(lambda x: str(x).replace('#', '') if isinstance(x, str) else x)\n\n# Merge the 'mdf' dataframe with 'folder_url_map_df' based on 'Folder_Number' and 'ID' columns\nmdf = mdf.merge(folder_url_map_df, left_on='Folder_Number', right_on='ID', how='left')\n\n# Drop 'ID' and 'Observations' columns from the 'mdf' dataframe as they are no longer needed\nmdf = mdf.drop(columns=['ID', 'Observations'])\n\n# Filter rows with non-null 'Links' column values\nfiltered_mdf = mdf.dropna(subset=['Links'])\n\n# Merge 'filtered_mdf' with 'combined_original_df' dataframe based on the 'Links' and 'source_url' columns\nmerged_data_with_org = filtered_mdf.merge(combined_original_df, left_on='Links', right_on='source_url', how='left')\n"

# %%
"""# Function to extract the domain from a URL
def extract_domain(url):
    try:
        # Use urlparse to extract the domain (netloc) from the URL
        return urlparse(url).netloc
    except:
        # Return None if the URL is invalid or an error occurs
        return None

# Apply the extract_domain function to 'source_url' and create a new column 'media_outlet'
merged_data_with_org['media_outlet'] = merged_data_with_org['source_url'].apply(extract_domain)

merged_data_with_org =merged_data_with_org[~merged_data_with_org['Company'].isin(['Unknown', 'Not specified'])]
# Count occurrences of each combination of 'Company' and 'media_outlet'
company_media_heatmap_data = (
    merged_data_with_org.groupby(['Company', 'media_outlet'])
    .size()
    .unstack(fill_value=0)
)

# Get the top 10 companies based on the total counts across all media outlets
top_10_companies = company_media_heatmap_data.sum(axis=1).nlargest(10).index

# Filter the heatmap data to only include the top 10 companies
company_media_heatmap_data_top_10 = company_media_heatmap_data.loc[top_10_companies]

# Count occurrences of each combination of 'Product' and 'media_outlet'
product_media_heatmap_data = (
    merged_data_with_org.groupby(['Product', 'media_outlet'])
    .size()
    .unstack(fill_value=0)
)

# Get the top 10 products based on the total counts across all media outlets
top_10_products = product_media_heatmap_data.sum(axis=1).nlargest(10).index

# Filter the heatmap data to only include the top 10 products
product_media_heatmap_data_top_10 = product_media_heatmap_data.loc[top_10_products]

# Plot heatmap for companies vs media outlets
plt.figure(figsize=(12, 8))
sns.heatmap(
    company_media_heatmap_data_top_10,
    cmap='coolwarm',
    annot=False,  # Do not annotate the heatmap cells
    fmt='d',      # Format the values as integers
    linewidths=0.5
)
plt.title('Heatmap of Companies vs Media Outlets')
plt.xlabel('Media Outlet')
plt.ylabel('Company')
plt.show()

# Plot heatmap for products vs media outlets
plt.figure(figsize=(12, 8))
sns.heatmap(
    product_media_heatmap_data_top_10,
    cmap='coolwarm',
    annot=False,  # Do not annotate the heatmap cells
    fmt='d',      # Format the values as integers
    linewidths=0.5
)
plt.title('Heatmap of Products vs Media Outlets')
plt.xlabel('Media Outlet')
plt.ylabel('Product')
plt.show()
"""
# Out:
# "# Function to extract the domain from a URL\ndef extract_domain(url):\n    try:\n        # Use urlparse to extract the domain (netloc) from the URL\n        return urlparse(url).netloc\n    except:\n        # Return None if the URL is invalid or an error occurs\n        return None\n\n# Apply the extract_domain function to 'source_url' and create a new column 'media_outlet'\nmerged_data_with_org['media_outlet'] = merged_data_with_org['source_url'].apply(extract_domain)\n\nmerged_data_with_org =merged_data_with_org[~merged_data_with_org['Company'].isin(['Unknown', 'Not specified'])]\n# Count occurrences of each combination of 'Company' and 'media_outlet'\ncompany_media_heatmap_data = (\n    merged_data_with_org.groupby(['Company', 'media_outlet'])\n    .size()\n    .unstack(fill_value=0)\n)\n\n# Get the top 10 companies based on the total counts across all media outlets\ntop_10_companies = company_media_heatmap_data.sum(axis=1).nlargest(10).index\n\n# Filter the heatmap data to only include the top 10 companies\ncompany_media_heatmap_data_top_10 = company_media_heatmap_data.loc[top_10_companies]\n\n# Count occurrences of each combination of 'Product' and 'media_outlet'\nproduct_media_heatmap_data = (\n    merged_data_with_org.groupby(['Product', 'media_outlet'])\n    .size()\n    .unstack(fill_value=0)\n)\n\n# Get the top 10 products based on the total counts across all media outlets\ntop_10_products = product_media_heatmap_data.sum(axis=1).nlargest(10).index\n\n# Filter the heatmap data to only include the top 10 products\nproduct_media_heatmap_data_top_10 = product_media_heatmap_data.loc[top_10_products]\n\n# Plot heatmap for companies vs media outlets\nplt.figure(figsize=(12, 8))\nsns.heatmap(\n    company_media_heatmap_data_top_10,\n    cmap='coolwarm',\n    annot=False,  # Do not annotate the heatmap cells\n    fmt='d',      # Format the values as integers\n    linewidths=0.5\n)\nplt.title('Heatmap of Companies vs Media Outlets')\nplt.xlabel('Media Outlet')\nplt.ylabel('Company')\nplt.show()\n\n# Plot heatmap for products vs media outlets\nplt.figure(figsize=(12, 8))\nsns.heatmap(\n    product_media_heatmap_data_top_10,\n    cmap='coolwarm',\n    annot=False,  # Do not annotate the heatmap cells\n    fmt='d',      # Format the values as integers\n    linewidths=0.5\n)\nplt.title('Heatmap of Products vs Media Outlets')\nplt.xlabel('Media Outlet')\nplt.ylabel('Product')\nplt.show()\n"

# %%
unicef_ads_data = mdf[(mdf['Company'].str.contains('UNICEF', case=False, na=False)) |
                      (mdf['Ad_Name'].str.contains('UNICEF', case=False, na=False))]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-174434d28d03> in <cell line: 1>()
# ----> 1 unicef_ads_data = mdf[(mdf['Company'].str.contains('UNICEF', case=False, na=False)) |
#       2                       (mdf['Ad_Name'].str.contains('UNICEF', case=False, na=False))]
#
# NameError: name 'mdf' is not defined

# %%
unicef_ads_data

# %%
sentiment_counts = unicef_ads_data['Sentiment'].value_counts()

# Plot sentiments as a bar chart
plt.figure(figsize=(8, 5))
sentiment_counts.plot(kind='bar', color=['green', 'orange', 'red'], alpha=0.7)
plt.title('Sentiment Distribution for UNICEF Ads')
plt.xlabel('Sentiment')
plt.ylabel('Number of Articles')
plt.xticks(rotation=0)
plt.show()

# %%
from wordcloud import WordCloud

# Combine all text from 'article_text' and 'headline'
text_data = ' '.join(unicef_ads_data['Article_Text'].fillna('')) + ' ' + ' '.join(unicef_ads_data['Headline'].fillna(''))

# Generate Word Cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_data)

# Plot Word Cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Topics in Articles advertising about UNICEF')
plt.show()

# %% [markdown]
# # Luis

# %% [markdown]
# ## Check if it's one screenshot per row

# %%
ads_df.Image_Link.value_counts()
# Out:
# Image_Link
# https://drive.google.com/file/d/1mPRlHe3Q4OFexGPwKaw-Q4PCqdaTm3AQ/view?usp=drivesdk    7
# https://drive.google.com/file/d/18t30_7W7wD6A8LWZlFO15iUExYLcWgB6/view?usp=drivesdk    6
# https://drive.google.com/file/d/15dlouMoCyWuduux-yoTkkrg1-H-bMOmx/view?usp=drivesdk    5
# https://drive.google.com/file/d/1bXlcYJquAKO5CnFvSexvsy4R9mK89_sO/view?usp=drivesdk    5
# https://drive.google.com/file/d/10qt9GCaN3P78S69zjuMyD9dtV8SxeIKw/view?usp=drivesdk    5
#                                                                                       ..
# https://drive.google.com/file/d/1rhXs_EiOMDslpQuid4BI64RVSTi0FZ8o/view?usp=drivesdk    1
# https://drive.google.com/file/d/1D48UWW42YEpnP-2n0DRx8quKdOLeNjDo/view?usp=drivesdk    1
# https://drive.google.com/file/d/1toeBbwGvL68DxKK1tC80C25FTr82RTNq/view?usp=drivesdk    1
# https://drive.google.com/file/d/1klPqRfudgMBLEfDZIAQVUdZisRXfVgLx/view?usp=drivesdk    1
# https://drive.google.com/file/d/1w1T1S4-y3HzMGHqrmfRXQER3xDiV9ENd/view?usp=drivesdk    1
# Name: count, Length: 1123, dtype: int64

# %% [markdown]
# ## Map placements to less granular categories

# %%
def mapper(s):
  s = s.lower()
  if 'sidebar' in s:
    return 'sidebar'
  elif 'inline' in s:
    return 'inline'
  elif 'top' in s:
    return 'top section'
  elif 'bottom' in s:
    return 'bottom section'
  elif 'middle' in s:
    return 'middle section'
  elif 'main' in s:
    return 'main section'
  elif 'corner' in s:
    return 'corner'
  elif 'banner' in s:
    return 'banner'
  elif 'popup' in s or 'pop-up' in s or 'pop up' in s:
    return 'popup'
  elif 'overlay' in s:
    return 'overlay'
  elif 'section' in s:
    return 'other section'
  elif 'body' in s:
    return 'article body'
  else:
    return 'other'

# %%
ads_df['Coarse_Ad_Placement'] = ads_df['Ad_Placement'].apply(mapper)

# %%
ads_df.Coarse_Ad_Placement.value_counts()
# Out:
# Coarse_Ad_Placement
# sidebar           889
# bottom section    341
# inline            204
# top section       181
# banner            125
# main section       56
# middle section     32
# overlay             7
# other               7
# other section       4
# popup               3
# Name: count, dtype: int64

# %%
ads_df[ads_df.Coarse_Ad_Placement=='other']
# Out:
#      Folder_Number                                         Image_Link  \
# 213            139  https://drive.google.com/file/d/1wYbwlVQ1Uk-aq...
# 242            548  https://drive.google.com/file/d/1qLmFofQy9IGnd...
# 677            139  https://drive.google.com/file/d/15Ia02wbUMSABw...
# 689            155  https://drive.google.com/file/d/1UOzbmKchG4LKq...
# 938            S05  https://drive.google.com/file/d/12zA1w1Ybh_G3X...
# 1209           723  https://drive.google.com/file/d/1b-vpF4TXkaWXK...
# 1480          M123  https://drive.google.com/file/d/1xgrOSECGMuJJ4...
#
#                        Ad_Name                          Product  \
# 213                       ySOY                      Music album
# 242   Alquiler Coches Canarias              Car Rental Services
# 677              Electroverano                 Electric Vehicle
# 689          Pickle Jar Advice                          Pickles
# 938            Generación €uro                Economic analysis
# 1209        VOLVER A SER PADRE                              NaN
# 1480      Fundación 'la Caixa'  Mental Health Inclusion Project
#
#                        Company  \
# 213              Amanda Miguel
# 242   Alquiler Coches Canarias
# 677                    Unknown
# 689                Unspecified
# 938              Not specified
# 1209                       NaN
# 1480      Fundación 'la Caixa'
#
#                                          Ad_Description  \
# 213   Promoting Amanda Miguel's music album titled '...
# 242          Car rental services in the Canary Islands.
# 677   An advertisement promoting electric vehicle se...
# 689   Advice on using honey or pickles when experien...
# 938   Sánchez: The Spanish economy is like Taylor Sw...
# 1209  This advertisement promotes a service or produ...
# 1480  Listen and assist young people with mental hea...
#
#                                Ad_Placement Coarse_Ad_Placement
# 213               Right side of the website               other
# 242                      Below the headline               other
# 677                      Center of the page               other
# 689                       Overlaid on image               other
# 938       Center of the page below headline               other
# 1209     center of the page, below headline               other
# 1480  center of the page before the article               other

# %% [markdown]
# ## Merge both dfs

# %%
def merge_ad_article_data(ads_df: pd.DataFrame, articles_df: pd.DataFrame) -> pd.DataFrame:
    """
    Merge ads and articles datasets based on matching image URLs.

    Parameters:
    -----------
    ads_df : DataFrame
        Dataset containing ad information with 'Image_Link' column
    articles_df : DataFrame
        Dataset containing article information with 'Image_Links' column (array/list)

    Returns:
    --------
    DataFrame
        Enhanced ads dataset with article metadata for each ad
    """
    # Create a mapping of image URLs to article metadata
    image_to_article = {}
    for _, article in articles_df.iterrows():
        # Convert string representation of list to actual list if needed
        if isinstance(article['Image_Links'], str):
            image_links = eval(article['Image_Links'])
        else:
            image_links = article['Image_Links']

        # Add article metadata for each image
        for img_url in image_links:
            image_to_article[img_url] = {
                'Published_Date': article['Published_Date'],
                'Sentiment': article['Sentiment'],
                'Tone': article['Tone'],
                'Article_Text': article['Article_Text'],
                'Headline': article['Headline'],
                'Publishing_Agency_Name': article['Publishing_Agency_Name'],
                'Keywords_Tags': article['Keywords_Tags'],
                'Related_Article_Links': article['Related_Article_Links'],
                'Narrative': article['Narrative']
                # Add any other article metadata you need
            }

    # Add article metadata to ads based on matching image URLs
    enhanced_ads = []
    unmatched_ads = []

    for _, ad in ads_df.iterrows():
        ad_data = ad.to_dict()
        if ad['Image_Link'] in image_to_article:
            ad_data.update(image_to_article[ad['Image_Link']])
            enhanced_ads.append(ad_data)
        else:
            unmatched_ads.append(ad['Image_Link'])

    # Create merged dataframe
    merged_df = pd.DataFrame(enhanced_ads)

    # Preprocess dates
    merged_df['Published_Date'] = pd.to_datetime(
        merged_df['Published_Date'],
        format='%d-%m-%Y',
        errors='coerce'
    )

    # Add derived date features
    merged_df['Month'] = merged_df['Published_Date'].dt.month
    merged_df['Month_Name'] = merged_df['Published_Date'].dt.month_name()
    merged_df['Weekday'] = merged_df['Published_Date'].dt.day_name()

    # Print matching statistics
    print(f"Total ads: {len(ads_df)}")
    print(f"Successfully matched ads: {len(enhanced_ads)}")
    print(f"Unmatched ads: {len(unmatched_ads)}")
    if unmatched_ads:
        print("\nSample of unmatched ad images:")
        for url in unmatched_ads[:5]:
            print(f"- {url}")

    return merged_df

# %%
mdf = merge_ad_article_data(ads_df,article_df)
# Out:
# Total ads: 1849
# Successfully matched ads: 1849
# Unmatched ads: 0

# %%
mdf.head(3)
# Out:
#   Folder_Number                                         Image_Link  \
# 0           567  https://drive.google.com/file/d/1hBdhtHJdH3RMB...
# 1           567  https://drive.google.com/file/d/1hBdhtHJdH3RMB...
# 2           567  https://drive.google.com/file/d/13dojG4THjVX9r...
#
#             Ad_Name                         Product           Company  \
# 0         AirEuropa                 Flight Services        Air Europa
# 1   El Corte Inglés  Electronics and IT accessories   El Corte Inglés
# 2  American Express                     Credit Card  American Express
#
#                                       Ad_Description Ad_Placement  \
# 0  Spain and Europe from 17 EUR, America from 246...      sidebar
# 1            IT store offering various tech products       inline
# 2              Get 800€ for your restaurant expenses      Sidebar
#
#   Coarse_Ad_Placement Published_Date Sentiment     Tone  \
# 0             sidebar     2024-01-30  Negative  Warning
# 1              inline     2024-01-30  Negative  Warning
# 2             sidebar     2024-01-30  Negative  Warning
#
#                                         Article_Text  \
# 0  Parallelly, it is necessary to develop Europea...
# 1  Parallelly, it is necessary to develop Europea...
# 2  Parallelly, it is necessary to develop Europea...
#
#                                             Headline Publishing_Agency_Name  \
# 0  Borrell: At this moment, the "softening" of Ru...               Informer
# 1  Borrell: At this moment, the "softening" of Ru...               Informer
# 2  Borrell: At this moment, the "softening" of Ru...               Informer
#
#                                        Keywords_Tags  \
# 0  ['Russia', 'Ukraine', 'EU', 'Borrell', 'Milita...
# 1  ['Russia', 'Ukraine', 'EU', 'Borrell', 'Milita...
# 2  ['Russia', 'Ukraine', 'EU', 'Borrell', 'Milita...
#
#                                Related_Article_Links  \
# 0  ['Moscow is on the verge! It is threatening al...
# 1  ['Moscow is on the verge! It is threatening al...
# 2  ['Moscow is on the verge! It is threatening al...
#
#                                            Narrative  Month Month_Name  \
# 0  The article conveys a critical stance on the i...    1.0    January
# 1  The article conveys a critical stance on the i...    1.0    January
# 2  The article conveys a critical stance on the i...    1.0    January
#
#    Weekday
# 0  Tuesday
# 1  Tuesday
# 2  Tuesday

# %% [markdown]
# ## Embedding analysis

# %%
# Part 1: Embedding Generation
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.manifold import TSNE

def generate_embeddings(df, column_name, perplexity=30, n_iter=1000):
    """Generate embeddings and reduce dimensionality using t-SNE"""
    # Clean data
    df[column_name] = df[column_name].fillna('')
    mask = df[column_name].str.len() > 0
    clean_data = df[mask]

    # Generate embeddings
    model = SentenceTransformer('all-MiniLM-L6-v2')
    embeddings = model.encode(clean_data[column_name].tolist(), show_progress_bar=True)

    # Apply t-SNE
    tsne = TSNE(n_components=2, perplexity=perplexity, n_iter=n_iter, random_state=42)
    embeddings_2d = tsne.fit_transform(embeddings)

    # Create DataFrame with embeddings and metadata
    embed_df = pd.DataFrame({
        'x': embeddings_2d[:, 0],
        'y': embeddings_2d[:, 1],
        'text': clean_data[column_name],
        'tone': clean_data['Tone'],
        'sentiment': clean_data['Sentiment'],
    })

    return embed_df


# Generate embeddings for Products and Companies
product_embeddings = generate_embeddings(mdf, 'Product')
company_embeddings = generate_embeddings(mdf, 'Company')
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/57 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# Batches:   0%|          | 0/53 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
company_embeddings.head(3)
# Out:
#            x          y              text     tone sentiment
# 0  17.123337  37.134735        Air Europa  Warning  Negative
# 1 -45.233994 -28.599485   El Corte Inglés  Warning  Negative
# 2  53.371426  -7.918920  American Express  Warning  Negative

# %%
product_embeddings.head(3)
# Out:
#            x          y                            text     tone sentiment
# 0 -32.158764 -26.771271                 Flight Services  Warning  Negative
# 1   6.000990   1.136810  Electronics and IT accessories  Warning  Negative
# 2 -39.504162   3.770920                     Credit Card  Warning  Negative

# %%
import plotly.express as px

# %%
# Cell 2: Product Embeddings by Sentiment
fig_product_sentiment = px.scatter(
    product_embeddings,
    x='x',
    y='y',
    color='sentiment',
    title='Products by Sentiment',
    color_discrete_sequence=px.colors.qualitative.Set1,
    hover_data={
        'x': False,
        'y': False,
        'text': True,
        'sentiment': True
    }
)

fig_product_sentiment.update_layout(
    title={
        'text': 'Products Clustered by Sentiment',
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top',
        'font': dict(size=24)
    },
    plot_bgcolor='white',
    width=1200,
    height=800,
    showlegend=True,
    legend=dict(
        title=dict(text='Sentiment Categories', font=dict(size=16)),
        font=dict(size=14),
        yanchor="top",
        y=0.99,
        xanchor="left",
        x=1.02
    )
)

fig_product_sentiment.update_traces(
    marker=dict(size=12, line=dict(width=1, color='DarkSlateGrey')),
    opacity=0.7
)

fig_product_sentiment.update_xaxes(title_text='t-SNE Dimension 1', title_font=dict(size=16), showgrid=True, gridwidth=1, gridcolor='LightGray')
fig_product_sentiment.update_yaxes(title_text='t-SNE Dimension 2', title_font=dict(size=16), showgrid=True, gridwidth=1, gridcolor='LightGray')

fig_product_sentiment.show()
# save fig to html
fig_product_sentiment.write_html("product_sentiment.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2faf091e-4ec7-4162-b36e-8c28c5f0e8b9" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2faf091e-4ec7-4162-b36e-8c28c5f0e8b9")) {                    Plotly.newPlot(                        "2faf091e-4ec7-4162-b36e-8c28c5f0e8b9",                        [{"customdata":[["Flight Services","Negative"],["Electronics and IT accessories","Negative"],["Credit Card","Negative"],["Hybrid Car","Negative"],["Credit Card","Negative"],["Credit Card","Negative"],["Political Campaign","Negative"],["Lifestyle article","Negative"],["Art Exhibition","Negative"],["Credit Card","Negative"],["Scratch removal tool","Negative"],["Hotel marketing services","Negative"],["Gardening","Negative"],["Social sharing","Negative"],["SUV","Negative"],["Travel services","Negative"],["Transportation services","Negative"],["Automotive Glass Service","Negative"],["Energy services","Negative"],["Energy plan","Negative"],["Dining experience","Negative"],["Service alert","Negative"],["Train service","Negative"],["TUCSON","Negative"],["train service","Negative"],["Event Cancellation","Negative"],["Zara","Negative"],["Football Replacement","Negative"],["Business Education","Negative"],["Business Education","Negative"],["MBAs Masters","Negative"],["Education","Negative"],["Theme Park","Negative"],["Tattoo ointment","Negative"],["Educational Programs for MBAs","Negative"],["Waterpark","Negative"],["Master's Degree Programs","Negative"],["Alopecia treatment","Negative"],["Storage Solutions","Negative"],["Video advertisement","Negative"],["Printed Pavement","Negative"],["Flight Tickets","Negative"],["News updates","Negative"],["Banking Services","Negative"],["News Article","Negative"],["Restaurant services","Negative"],["Sports apparel and footwear","Negative"],["News subscription","Negative"],["Nike products","Negative"],["Cargo shorts","Negative"],["Nike Factory","Negative"],["Drone Corps","Negative"],["Men's Cargo Shorts","Negative"],["Nike Apparel","Negative"],["Financial Analysis","Negative"],["Concert","Negative"],["Nike products","Negative"],["Local business\u002frestaurant","Negative"],["Online news article","Negative"],["Monthly payment plan for motorcycle","Negative"],["Online store","Negative"],["Online News","Negative"],["News Section","Negative"],["Monster service or product","Negative"],["Personal story or testimonial","Negative"],["Personal story or testimonial","Negative"],["Article","Negative"],["Article","Negative"],["Airline Services","Negative"],["Hotel Services","Negative"],["Beauty Products","Negative"],["Hotel Stay","Negative"],["Adidas Shoes","Negative"],["Flight Booking","Negative"],["Apparel","Negative"],["Automobile and Automotive Technology Magazine","Negative"],["Historical Publication","Negative"],["Technology Magazine","Negative"],["Historical Publication","Negative"],["Historical Publication","Negative"],["Nutrition Calculator","Negative"],["Minipimer","Negative"],["[Not provided in screenshot]","Negative"],["Mobile Service","Negative"],["Car","Negative"],["Mobile Service","Negative"],["Peugeot 2008","Negative"],["Mobile plan","Negative"],["Mobile Plan","Negative"],["Application Deadline","Negative"],["Advertisement","Negative"],["Advertisement","Negative"],["Advertisement","Negative"],["KAMIQ ESSENCE 1.0 TSI 70KW (95CV) Manual","Negative"],["Wicker Egg Chair","Negative"],["Printer with Ink","Negative"],["Clothing","Negative"],["Skoda Car","Negative"],["Clothing","Negative"],["4-Piece Luggage Set","Negative"],["Dyson V8 Origin+","Negative"],["Clothing","Negative"],["Luggage Set","Negative"],["Vacuum Cleaner","Negative"],["Energy Services","Negative"],["Electric utility service","Negative"],["Automobiles","Negative"],["WordPress Hosting ...

# %%
# Cell 1: Product Embeddings Visualization
import plotly.express as px

# Create Product visualization by Tone
fig_product_tone = px.scatter(
    product_embeddings,
    x='x',
    y='y',
    color='tone',
    title='Product Embeddings by Tone',
    color_discrete_sequence=px.colors.qualitative.Set3,
    hover_data={
        'x': False,
        'y': False,
        'text': True,
        'tone': True
    }
)

fig_product_tone.update_layout(
    title={
        'text': 'Product Embeddings Clustered by Tone',
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top',
        'font': dict(size=24)
    },
    plot_bgcolor='white',
    width=1200,
    height=800,
    showlegend=True,
    legend=dict(
        title=dict(text='Tone Categories', font=dict(size=16)),
        font=dict(size=14),
        yanchor="top",
        y=0.99,
        xanchor="left",
        x=1.02
    )
)

fig_product_tone.update_traces(
    marker=dict(size=12, line=dict(width=1, color='DarkSlateGrey')),
    opacity=0.7
)

fig_product_tone.update_xaxes(title_text='t-SNE Dimension 1', title_font=dict(size=16), showgrid=True, gridwidth=1, gridcolor='LightGray')
fig_product_tone.update_yaxes(title_text='t-SNE Dimension 2', title_font=dict(size=16), showgrid=True, gridwidth=1, gridcolor='LightGray')

fig_product_tone.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3d977016-a6a8-4e87-8963-8bcf8a79f122" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d977016-a6a8-4e87-8963-8bcf8a79f122")) {                    Plotly.newPlot(                        "3d977016-a6a8-4e87-8963-8bcf8a79f122",                        [{"customdata":[["Flight Services","Warning"],["Electronics and IT accessories","Warning"],["Credit Card","Warning"],["Hybrid Car","Warning"],["Credit Card","Warning"],["Credit Card","Warning"],["Political Campaign","Warning"],["Lifestyle article","Warning"],["Art Exhibition","Warning"],["Credit Card","Warning"]],"hovertemplate":"tone=%{customdata[1]}\u003cbr\u003etext=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Warning","marker":{"color":"rgb(141,211,199)","symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"size":12},"mode":"markers","name":"Warning","showlegend":true,"x":[-32.158764,6.0009904,-39.50416,26.368982,-39.50416,-39.50416,25.298826,15.726496,24.389988,-38.78677],"xaxis":"x","y":[-26.77127,1.1368103,3.7709196,-46.154198,3.7709196,3.7709196,43.37617,51.31127,20.437935,2.510889],"yaxis":"y","type":"scattergl","opacity":0.7},{"customdata":[["Mobile Services","Inquisitive"],["Mobile plans","Inquisitive"],["Mobile phone service","Inquisitive"],["Sorolla Exhibition","Inquisitive"],["Expo","Inquisitive"],["Smart beds","Inquisitive"],["Garden pools","Inquisitive"],["Mobile service","Inquisitive"],["Mobile service","Inquisitive"],["Swimming pool","Inquisitive"],["Smart bed","Inquisitive"]],"hovertemplate":"tone=%{customdata[1]}\u003cbr\u003etext=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Inquisitive","marker":{"color":"rgb(255,255,179)","symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"size":12},"mode":"markers","name":"Inquisitive","showlegend":true,"x":[-33.050346,-36.92356,-30.897642,26.696018,24.258326,-0.6416064,12.870953,-32.482605,-32.549164,12.911047,-0.7662798],"xaxis":"x","y":[24.952694,23.965364,24.197426,20.086918,22.748236,-11.543411,-31.758947,24.01977,24.15825,-31.701561,-11.39698],"yaxis":"y","type":"scattergl","opacity":0.7},{"customdata":[["Home Improvement","Informative"],["Car Scratch Removal","Informative"],["Museum visit","Informative"],["Skincare and beauty advice","Informative"],["Museum Entry","Informative"],["Kitchen appliances","Informative"],["Travel services","Informative"],["Hybrid Vehicle","Informative"],["Hybrid Vehicle","Informative"],["Mobile service","Informative"],["Car","Informative"],["Hybrid Car","Informative"],["Probiotic Yogurt Drink","Informative"],["Automobile","Informative"],["Educational Program","Informative"],["Charitable Support","Informative"],["Car","Informative"],["Educational Programs","Informative"],["Health and Wellness","Informative"],["Car","Informative"],["Airline Services","Informative"],["Hotel Services","Informative"],["Beauty Products","Informative"],["Hotel Stay","Informative"],["Adidas Shoes","Informative"],["Flight Booking","Informative"],["Apparel","Informative"],["Life Insurance","Informative"],["Creative Software Suite","Informative"],["Hotel Booking Discount","Informative"],["Flight Booking","Informative"],["Rewards Program","Informative"],["Car Maintenance Service","Informative"],["Automobile Magazine","Informative"],["History Magazine","Informative"],["Awareness Campaign","Informative"],["Electric Bike","Informative"],["News Highlights","Informative"],["Hotels & Homes","Informative"],["Instagram Page","Informative"],["Video Content","Informative"],["Online Security Services","Informative"],["Vitamin C Supplements","Informative"],["Online Insurance Services","Informative"],["Promotional Catalog","Informative"],["Content abo ...

# %%
# Cell 2: Product Embeddings by Sentiment
fig_product_sentiment = px.scatter(
    product_embeddings,
    x='x',
    y='y',
    color='sentiment',
    title='Product Embeddings by Sentiment',
    color_discrete_sequence=px.colors.qualitative.Set1,
    hover_data={
        'x': False,
        'y': False,
        'text': True,
        'sentiment': True
    }
)

fig_product_sentiment.update_layout(
    title={
        'text': 'Product Embeddings Clustered by Sentiment',
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top',
        'font': dict(size=24)
    },
    plot_bgcolor='white',
    width=1200,
    height=800,
    showlegend=True,
    legend=dict(
        title=dict(text='Sentiment Categories', font=dict(size=16)),
        font=dict(size=14),
        yanchor="top",
        y=0.99,
        xanchor="left",
        x=1.02
    )
)

fig_product_sentiment.update_traces(
    marker=dict(size=12, line=dict(width=1, color='DarkSlateGrey')),
    opacity=0.7
)

fig_product_sentiment.update_xaxes(title_text='t-SNE Dimension 1', title_font=dict(size=16), showgrid=True, gridwidth=1, gridcolor='LightGray')
fig_product_sentiment.update_yaxes(title_text='t-SNE Dimension 2', title_font=dict(size=16), showgrid=True, gridwidth=1, gridcolor='LightGray')

fig_product_sentiment.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dc0d5db9-831c-4d4b-baad-b8af7df0fe97" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc0d5db9-831c-4d4b-baad-b8af7df0fe97")) {                    Plotly.newPlot(                        "dc0d5db9-831c-4d4b-baad-b8af7df0fe97",                        [{"customdata":[["Flight Services","Negative"],["Electronics and IT accessories","Negative"],["Credit Card","Negative"],["Hybrid Car","Negative"],["Credit Card","Negative"],["Credit Card","Negative"],["Political Campaign","Negative"],["Lifestyle article","Negative"],["Art Exhibition","Negative"],["Credit Card","Negative"],["Scratch removal tool","Negative"],["Hotel marketing services","Negative"],["Gardening","Negative"],["Social sharing","Negative"],["SUV","Negative"],["Travel services","Negative"],["Transportation services","Negative"],["Automotive Glass Service","Negative"],["Energy services","Negative"],["Energy plan","Negative"],["Dining experience","Negative"],["Service alert","Negative"],["Train service","Negative"],["TUCSON","Negative"],["train service","Negative"],["Event Cancellation","Negative"],["Zara","Negative"],["Football Replacement","Negative"],["Business Education","Negative"],["Business Education","Negative"],["MBAs Masters","Negative"],["Education","Negative"],["Theme Park","Negative"],["Tattoo ointment","Negative"],["Educational Programs for MBAs","Negative"],["Waterpark","Negative"],["Master's Degree Programs","Negative"],["Alopecia treatment","Negative"],["Storage Solutions","Negative"],["Video advertisement","Negative"],["Printed Pavement","Negative"],["Flight Tickets","Negative"],["News updates","Negative"],["Banking Services","Negative"],["News Article","Negative"],["Restaurant services","Negative"],["Sports apparel and footwear","Negative"],["News subscription","Negative"],["Nike products","Negative"],["Cargo shorts","Negative"],["Nike Factory","Negative"],["Drone Corps","Negative"],["Men's Cargo Shorts","Negative"],["Nike Apparel","Negative"],["Financial Analysis","Negative"],["Concert","Negative"],["Nike products","Negative"],["Local business\u002frestaurant","Negative"],["Online news article","Negative"],["Monthly payment plan for motorcycle","Negative"],["Online store","Negative"],["Online News","Negative"],["News Section","Negative"],["Monster service or product","Negative"],["Personal story or testimonial","Negative"],["Personal story or testimonial","Negative"],["Article","Negative"],["Article","Negative"],["Airline Services","Negative"],["Hotel Services","Negative"],["Beauty Products","Negative"],["Hotel Stay","Negative"],["Adidas Shoes","Negative"],["Flight Booking","Negative"],["Apparel","Negative"],["Automobile and Automotive Technology Magazine","Negative"],["Historical Publication","Negative"],["Technology Magazine","Negative"],["Historical Publication","Negative"],["Historical Publication","Negative"],["Nutrition Calculator","Negative"],["Minipimer","Negative"],["[Not provided in screenshot]","Negative"],["Mobile Service","Negative"],["Car","Negative"],["Mobile Service","Negative"],["Peugeot 2008","Negative"],["Mobile plan","Negative"],["Mobile Plan","Negative"],["Application Deadline","Negative"],["Advertisement","Negative"],["Advertisement","Negative"],["Advertisement","Negative"],["KAMIQ ESSENCE 1.0 TSI 70KW (95CV) Manual","Negative"],["Wicker Egg Chair","Negative"],["Printer with Ink","Negative"],["Clothing","Negative"],["Skoda Car","Negative"],["Clothing","Negative"],["4-Piece Luggage Set","Negative"],["Dyson V8 Origin+","Negative"],["Clothing","Negative"],["Luggage Set","Negative"],["Vacuum Cleaner","Negative"],["Energy Services","Negative"],["Electric utility service","Negative"],["Automobiles","Negative"],["WordPress Hosting ...

# %%
# Cell 3: Company Embeddings by Tone
fig_company_tone = px.scatter(
    company_embeddings,
    x='x',
    y='y',
    color='tone',
    title='Company Embeddings by Tone',
    color_discrete_sequence=px.colors.qualitative.Set3,
    hover_data={
        'x': False,
        'y': False,
        'text': True,
        'tone': True
    }
)

fig_company_tone.update_layout(
    title={
        'text': 'Company Embeddings Clustered by Tone',
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top',
        'font': dict(size=24)
    },
    plot_bgcolor='white',
    width=1200,
    height=800,
    showlegend=True,
    legend=dict(
        title=dict(text='Tone Categories', font=dict(size=16)),
        font=dict(size=14),
        yanchor="top",
        y=0.99,
        xanchor="left",
        x=1.02
    )
)

fig_company_tone.update_traces(
    marker=dict(size=12, line=dict(width=1, color='DarkSlateGrey')),
    opacity=0.7
)

fig_company_tone.update_xaxes(title_text='t-SNE Dimension 1', title_font=dict(size=16), showgrid=True, gridwidth=1, gridcolor='LightGray')
fig_company_tone.update_yaxes(title_text='t-SNE Dimension 2', title_font=dict(size=16), showgrid=True, gridwidth=1, gridcolor='LightGray')

fig_company_tone.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0f6b1dc8-bdd4-48d7-a5b6-445d4a6eb25a" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f6b1dc8-bdd4-48d7-a5b6-445d4a6eb25a")) {                    Plotly.newPlot(                        "0f6b1dc8-bdd4-48d7-a5b6-445d4a6eb25a",                        [{"customdata":[["Air Europa","Warning"],["El Corte Inglés","Warning"],["American Express","Warning"],["Renault","Warning"],["American Express","Warning"],["American Express","Warning"],["Informers","Warning"],["XYZ Media","Warning"],["Sorolla Expo Barcelona","Warning"],["American Express","Warning"]],"hovertemplate":"tone=%{customdata[1]}\u003cbr\u003etext=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Warning","marker":{"color":"rgb(141,211,199)","symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"size":12},"mode":"markers","name":"Warning","showlegend":true,"x":[17.123337,-45.233994,53.371426,19.470863,53.371426,53.371426,4.257787,23.389774,-59.73956,55.15295],"xaxis":"x","y":[37.134735,-28.599485,-7.9189196,9.084692,-7.9189196,-7.9189196,-55.747715,50.29055,-35.57494,-7.865867],"yaxis":"y","type":"scattergl","opacity":0.7},{"customdata":[["Simyo","Inquisitive"],["simyo","Inquisitive"],["Simyo","Inquisitive"],["Sorolla Expo Barcelona","Inquisitive"],["Sorolla","Inquisitive"],["Camás inteligentes","Inquisitive"],["Pisinas de jardín asequibles","Inquisitive"],["Simyo","Inquisitive"],["Simyo","Inquisitive"],["Quinielas | Enlaces Publicitarios","Inquisitive"],["Camas inteligentes | Enlaces Publicitarios","Inquisitive"]],"hovertemplate":"tone=%{customdata[1]}\u003cbr\u003etext=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Inquisitive","marker":{"color":"rgb(255,255,179)","symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"size":12},"mode":"markers","name":"Inquisitive","showlegend":true,"x":[-71.59937,-71.59937,-71.59937,-59.73956,-65.283325,-29.201788,-46.468254,-71.59937,-70.6514,-30.404755,-29.890879],"xaxis":"x","y":[1.0952672,1.0952672,1.0952672,-35.57494,-31.371185,-39.273514,-30.836384,1.0952672,2.8103147,-35.72457,-37.578224],"yaxis":"y","type":"scattergl","opacity":0.7},{"customdata":[["Not specified","Informative"],["Not specified","Informative"],["Museu Terra","Informative"],["Midas","Informative"],["Museu Terra","Informative"],["SWISS","Informative"],["Renault","Informative"],["Renault","Informative"],["O2","Informative"],["Renault","Informative"],["Renault","Informative"],["Danone","Informative"],["Renault","Informative"],["EAE","Informative"],["UNICEF","Informative"],["Renault","Informative"],["EADE","Informative"],["Glenitener","Informative"],["Renault","Informative"],["Vueling","Informative"],["MELIÁ Hotels & Resorts","Informative"],["Bio-Oil","Informative"],["MELIA","Informative"],["Adidas","Informative"],["Vueling","Informative"],["Adidas","Informative"],["Allianz","Informative"],["Adobe","Informative"],["Meliá Hotels International","Informative"],["Vueling","Informative"],["MELIA","Informative"],["Renault","Informative"],["Drive","Informative"],["History","Informative"],["Greenpeace","Informative"],["Fiido EU","Informative"],["ProNews","Informative"],["MarSenses","Informative"],["pronews.gr","Informative"],["pronews","Informative"],["ISEO","Informative"],["Intermed","Informative"],["Sigal","Informative"],["Spar","Informative"],["Sponsored by Passion for Life","Informative"],["Hungarian Defense Forces","Informative"],["PS TV","Informative"],["[Company not provided]","Informative"],["Freshly","Informative"],["Freshly","Informative"],["Freshly","Informative"],["inbestMe","Informative"],["Meliã","Informative"],["Freshly","Informative"],["inbestMe","Informative"],["Meliá Hotels Internation ...

# %%
# Cell 4: Company Embeddings by Sentiment
fig_company_sentiment = px.scatter(
    company_embeddings,
    x='x',
    y='y',
    color='sentiment',
    title='Company Embeddings by Sentiment',
    color_discrete_sequence=px.colors.qualitative.Set1,
    hover_data={
        'x': False,
        'y': False,
        'text': True,
        'sentiment': True
    }
)

fig_company_sentiment.update_layout(
    title={
        'text': 'Company Embeddings Clustered by Sentiment',
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top',
        'font': dict(size=24)
    },
    plot_bgcolor='white',
    width=1200,
    height=800,
    showlegend=True,
    legend=dict(
        title=dict(text='Sentiment Categories', font=dict(size=16)),
        font=dict(size=14),
        yanchor="top",
        y=0.99,
        xanchor="left",
        x=1.02
    )
)

fig_company_sentiment.update_traces(
    marker=dict(size=12, line=dict(width=1, color='DarkSlateGrey')),
    opacity=0.7
)

fig_company_sentiment.update_xaxes(title_text='t-SNE Dimension 1', title_font=dict(size=16), showgrid=True, gridwidth=1, gridcolor='LightGray')
fig_company_sentiment.update_yaxes(title_text='t-SNE Dimension 2', title_font=dict(size=16), showgrid=True, gridwidth=1, gridcolor='LightGray')

fig_company_sentiment.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d42fb0ad-2432-4ddb-a418-66e8c2ef3414" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d42fb0ad-2432-4ddb-a418-66e8c2ef3414")) {                    Plotly.newPlot(                        "d42fb0ad-2432-4ddb-a418-66e8c2ef3414",                        [{"customdata":[["Air Europa","Negative"],["El Corte Inglés","Negative"],["American Express","Negative"],["Renault","Negative"],["American Express","Negative"],["American Express","Negative"],["Informers","Negative"],["XYZ Media","Negative"],["Sorolla Expo Barcelona","Negative"],["American Express","Negative"],["Unknown","Negative"],["Unknown","Negative"],["Not specified","Negative"],["Not specified","Negative"],["Hyundai","Negative"],["Barcelo","Negative"],["WABI","Negative"],["Cary Group","Negative"],["Repsol","Negative"],["Octopus Energy","Negative"],["Trainline","Negative"],["Hyundai","Negative"],["trainline","Negative"],["EAE","Negative"],["EAE","Negative"],["EAE Business School Barcelona","Negative"],["EAE Business School","Negative"],["Parc Asterix","Negative"],["Bepanthol","Negative"],["EAE Business School Barcelona","Negative"],["VDO.AI","Negative"],["EAE Business School Barcelona","Negative"],["Aidenmar Campos","Negative"],["OhMyBox","Negative"],["VDO.AI","Negative"],["Pavimento Impreso Catalunya","Negative"],["Air Europa","Negative"],["Informer","Negative"],["ABANCA","Negative"],["Unknown","Negative"],["Nike","Negative"],["Asia Times","Negative"],["Nike","Negative"],["Nike","Negative"],["AsiaTimes","Negative"],["Unknown","Negative"],["Nike","Negative"],["AsiaTimes","Negative"],["Palau de la Música Catalana","Negative"],["Nike","Negative"],["AsiaTimes","Negative"],["Informer","Negative"],["Informer","Negative"],["Monster","Negative"],["Unknown","Negative"],["Unknown","Negative"],["Not specified","Negative"],["Not specified","Negative"],["Vueling","Negative"],["MELIÁ Hotels & Resorts","Negative"],["Bio-Oil","Negative"],["MELIA","Negative"],["Adidas","Negative"],["Vueling","Negative"],["Adidas","Negative"],["Drive Magazine","Negative"],["History Magazine","Negative"],["E-Tech Magazine","Negative"],["Extra History Magazine","Negative"],["History Aikaterini Magazine","Negative"],["Unknown","Negative"],["Braun","Negative"],["Membrana Media","Negative"],["simyo","Negative"],["Peugeot","Negative"],["simyo","Negative"],["Peugeot","Negative"],["simyo","Negative"],["Simyo","Negative"],["Government of Greece","Negative"],["Omet l'anunci","Negative"],["Google Ads","Negative"],["fiveri","Negative"],["Skoda","Negative"],["Amazon","Negative"],["HP","Negative"],["Various","Negative"],["Skoda","Negative"],["Various Retailers","Negative"],["Unspecified Retailer","Negative"],["Walmart","Negative"],["Walmart","Negative"],["Unknown","Negative"],["Barcelona Energia","Negative"],["SKODA","Negative"],["interdominoss","Negative"],["Coalza Systems S.L.","Negative"],["Ayuda en Acción","Negative"],["Kang Videncia y Tarot","Negative"],["Acer","Negative"],["Acer","Negative"],["Vueling","Negative"],["Acer","Negative"],["Acer","Negative"],["Peugeot","Negative"],["Vueling","Negative"],["Peugeot","Negative"],["Acer","Negative"],["Securitas Direct","Negative"],["Palau de la Música","Negative"],["Aiper","Negative"],["Acer","Negative"],["Aiper","Negative"],["Acer","Negative"],["Acer","Negative"],["Vueling Airlines","Negative"],["Openbank","Negative"],["Openbank","Negative"],["7Dnevno.hr","Negative"],["Vueling","Negative"],["Keto Slim","Negative"],["Osteax","Negative"],["Hondro Sol","Negative"],["Keto Matcha Blue","Negative"],["Keto Slim","Negative"],["OsteX","Negative"],["Hondro Sol","Negative"],["Keto Matcha Blue","Negative"],["Unknown","Negative"],["[Not provided]","Negative"],["PRONEWS","Negative ...

# %% [markdown]
# ## Most freq product/company per sentiment/tone

# %%
mdf.Publishing_Agency_Name
# Out:
# 0           Informer
# 1           Informer
# 2           Informer
# 3           Informer
# 4           Informer
#             ...
# 1844     Vizion Plus
# 1845    CNN Portugal
# 1846    CNN Portugal
# 1847    CNN Portugal
# 1848    CNN Portugal
# Name: Publishing_Agency_Name, Length: 1849, dtype: object

# %%
mdf[(mdf.Company.notna()) & (mdf.Company.apply(len) > 3)]
# Out:
#      Folder_Number                                         Image_Link  \
# 0              567  https://drive.google.com/file/d/1hBdhtHJdH3RMB...
# 1              567  https://drive.google.com/file/d/1hBdhtHJdH3RMB...
# 2              567  https://drive.google.com/file/d/13dojG4THjVX9r...
# 3              567  https://drive.google.com/file/d/1XbPaEeQVV5FmL...
# 4              567  https://drive.google.com/file/d/1XbPaEeQVV5FmL...
# ...            ...                                                ...
# 1843           M11  https://drive.google.com/file/d/1awAqhTY_oZJ--...
# 1844           M11  https://drive.google.com/file/d/1awAqhTY_oZJ--...
# 1845            M9  https://drive.google.com/file/d/1oYSICK-ISBshz...
# 1846            M9  https://drive.google.com/file/d/1mUcfWrpJ6rMEQ...
# 1847            M9  https://drive.google.com/file/d/1cnOY4VCSnYbHs...
#
#                               Ad_Name                         Product  \
# 0                           AirEuropa                 Flight Services
# 1                     El Corte Inglés  Electronics and IT accessories
# 2                    American Express                     Credit Card
# 3     Renault Clio E-Tech Full Hybrid                      Hybrid Car
# 4         American Express Card Offer                     Credit Card
# ...                               ...                             ...
# 1843                            Fanta                      Soft Drink
# 1844                   Coca-Cola Zero                      Soft Drink
# 1845                            VERSA                        Footwear
# 1846                          Unknown                  Lifestyle News
# 1847                    Travel Cruise          Online Cruise Services
#
#                Company                                     Ad_Description  \
# 0           Air Europa  Spain and Europe from 17 EUR, America from 246...
# 1      El Corte Inglés            IT store offering various tech products
# 2     American Express              Get 800€ for your restaurant expenses
# 3              Renault  Introducing the new Renault Clio with full hyb...
# 4     American Express  Get 800€* to spend in restaurants with the Ame...
# ...                ...                                                ...
# 1843         Coca-Cola                        Try the new taste of Fanta.
# 1844         Coca-Cola             Enjoy a Coca-Cola Zero with your meal.
# 1845           Unknown       Advertisement promoting a brand of footwear.
# 1846           Unknown  News about lifestyle that tells you what is ha...
# 1847    Aurora Project  Purchased an online cruise and spent over one ...
#
#                           Ad_Placement Coarse_Ad_Placement Published_Date  \
# 0                              sidebar             sidebar     2024-01-30
# 1                               inline              inline     2024-01-30
# 2                              Sidebar             sidebar     2024-01-30
# 3                              sidebar             sidebar     2024-01-30
# 4                               banner              banner     2024-01-30
# ...                                ...                 ...            ...
# 1843     Banner at the top of the page         top section     2023-10-06
# 1844  Inline advertisement on the page              inline     2023-10-06
# 1845                           Sidebar             sidebar     2023-10-18
# 1846                           Sidebar             sidebar     2023-10-18
# 1847              Main article section        main section     2023-10-18
#
#      Sentiment         Tone  \
# 0     Negative      Warning
# 1     Negative      Warning
# 2     Negative      Warning
# 3     Negative      Warning
# 4     Negative      Warning
# ...        ...          ...
# 1843   Neutral  Informative
# 1844   Neutral  Informative
# 1845   Neutral  Informative
# 1846   Neutral  Informative
# 1847   Neutral  Informative
#
#                                            Article_Text  \
# 0     Parallelly, it is necessary to develop Europea...
# 1     Parallelly, it is necessary to develop Europea...
# 2     Parallelly, it is necessary to develop Europea...
# 3     Parallelly, it is necessary to develop Europea...
# 4     Parallelly, it is necessary to develop Europea...
# ...                                                 ...
# 1843  Duelet spektakolare nga LIGA E KAMPIONËVE, kom...
# 1844  Duelet spektakolare nga LIGA E KAMPIONËVE, kom...
# 1845  PSD wants users of TVDE to be able to choose d...
# 1846  PSD wants users of TVDE to be able to choose d...
# 1847  PSD wants users of TVDE to be able to choose d...
#
#                                                Headline  \
# 0     Borrell: At this moment, the "softening" of Ru...
# 1     Borrell: At this moment, the "softening" of Ru...
# 2     Borrell: At this moment, the "softening" of Ru...
# 3     Borrell: At this moment, the "softening" of Ru...
# 4     Borrell: At this moment, the "softening" of Ru...
# ...                                                 ...
# 1843  Giigantët e futbollit “në aksion” dhe filmat e...
# 1844  Giigantët e futbollit “në aksion” dhe filmat e...
# 1845  LIVE | Santos Silva denies interference in the...
# 1846  LIVE | Santos Silva denies interference in the...
# 1847  LIVE | Santos Silva denies interference in the...
#
#      Publishing_Agency_Name  \
# 0                  Informer
# 1                  Informer
# 2                  Informer
# 3                  Informer
# 4                  Informer
# ...                     ...
# 1843            Vizion Plus
# 1844            Vizion Plus
# 1845           CNN Portugal
# 1846           CNN Portugal
# 1847           CNN Portugal
#
#                                           Keywords_Tags  \
# 0     ['Russia', 'Ukraine', 'EU', 'Borrell', 'Milita...
# 1     ['Russia', 'Ukraine', 'EU', 'Borrell', 'Milita...
# 2     ['Russia', 'Ukraine', 'EU', 'Borrell', 'Milita...
# 3     ['Russia', 'Ukraine', 'EU', 'Borrell', 'Milita...
# 4     ['Russia', 'Ukraine', 'EU', 'Borrell', 'Milita...
# ...                                                 ...
# 1843  ['football', 'sports', 'Champions League', 'TR...
# 1844  ['football', 'sports', 'Champions League', 'TR...
# 1845  ['Santos Silva', 'interference', 'twins', 'PS'...
# 1846  ['Santos Silva', 'interference', 'twins', 'PS'...
# 1847  ['Santos Silva', 'interference', 'twins', 'PS'...
#
#                                   Related_Article_Links  \
# 0     ['Moscow is on the verge! It is threatening al...
# 1     ['Moscow is on the verge! It is threatening al...
# 2     ['Moscow is on the verge! It is threatening al...
# 3     ['Moscow is on the verge! It is threatening al...
# 4     ['Moscow is on the verge! It is threatening al...
# ...                                                 ...
# 1843      ['Upcoming sports events', 'Sports analysis']
# 1844      ['Upcoming sports events', 'Sports analysis']
# 1845                                                 []
# 1846                                                 []
# 1847                                                 []
#
#                                               Narrative  Month Month_Name  \
# 0     The article conveys a critical stance on the i...    1.0    January
# 1     The article conveys a critical stance on the i...    1.0    January
# 2     The article conveys a critical stance on the i...    1.0    January
# 3     The article conveys a critical stance on the i...    1.0    January
# 4     The article conveys a critical stance on the i...    1.0    January
# ...                                                 ...    ...        ...
# 1843  The article presents an overview of upcoming f...   10.0    October
# 1844  The article presents an overview of upcoming f...   10.0    October
# 1845  The article discusses Santos Silva's denial of...   10.0    October
# 1846  The article discusses Santos Silva's denial of...   10.0    October
# 1847  The article discusses Santos Silva's denial of...   10.0    October
#
#         Weekday
# 0       Tuesday
# 1       Tuesday
# 2       Tuesday
# 3       Tuesday
# 4       Tuesday
# ...         ...
# 1843     Friday
# 1844     Friday
# 1845  Wednesday
# 1846  Wednesday
# 1847  Wednesday
#
# [1611 rows x 20 columns]

# %%
# Prepare data for each sentiment

mdf_filt = mdf[(mdf.Company.notna()) & (mdf.Company.apply(len) > 3)]
mdf_filt = mdf_filt[~mdf_filt.Company.isin(['[Unknown]', '[Not specified]', 'Unknown'])]
mdf_filt = mdf_filt[~mdf_filt.Company.isin(['Not specified', '[Not specified]', 'Unknown'])]

positive_companies = mdf_filt[mdf_filt['Sentiment'] == 'Positive']['Company'].value_counts().head(10)
negative_companies = mdf_filt[mdf_filt['Sentiment'] == 'Negative']['Company'].value_counts().head(10)
neutral_companies = mdf_filt[mdf_filt['Sentiment'] == 'Neutral']['Company'].value_counts().head(10)

# Create three separate bar plots
import plotly.graph_objects as go

# Plot for Positive Sentiment
fig_positive = go.Figure()
fig_positive.add_trace(go.Bar(
   x=positive_companies.index,
   y=positive_companies.values,
   marker_color='#2ecc71'
))

fig_positive.update_layout(
   title='Top 10 Companies in Positive Sentiment Articles',
   xaxis_title='Company',
   yaxis_title='Frequency',
   width=1000,
   height=600,
   plot_bgcolor='white',
   title_x=0.5,
   title_font_size=20,
   xaxis_tickangle=45
)
fig_positive.update_xaxes(showgrid=True, gridwidth=1, gridcolor='LightGray')
fig_positive.update_yaxes(showgrid=True, gridwidth=1, gridcolor='LightGray')
fig_positive.show()

# Plot for Negative Sentiment
fig_negative = go.Figure()
fig_negative.add_trace(go.Bar(
   x=negative_companies.index,
   y=negative_companies.values,
   marker_color='#e74c3c'
))

fig_negative.update_layout(
   title='Top 10 Companies in Negative Sentiment Articles',
   xaxis_title='Company',
   yaxis_title='Frequency',
   width=1000,
   height=600,
   plot_bgcolor='white',
   title_x=0.5,
   title_font_size=20,
   xaxis_tickangle=45
)
fig_negative.update_xaxes(showgrid=True, gridwidth=1, gridcolor='LightGray')
fig_negative.update_yaxes(showgrid=True, gridwidth=1, gridcolor='LightGray')
fig_negative.show()

# Plot for Neutral Sentiment
fig_neutral = go.Figure()
fig_neutral.add_trace(go.Bar(
   x=neutral_companies.index,
   y=neutral_companies.values,
   marker_color='#3498db'
))

fig_neutral.update_layout(
   title='Top 10 Companies in Neutral Sentiment Articles',
   xaxis_title='Company',
   yaxis_title='Frequency',
   width=1000,
   height=600,
   plot_bgcolor='white',
   title_x=0.5,
   title_font_size=20,
   xaxis_tickangle=45
)
fig_neutral.update_xaxes(showgrid=True, gridwidth=1, gridcolor='LightGray')
fig_neutral.update_yaxes(showgrid=True, gridwidth=1, gridcolor='LightGray')
fig_neutral.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="07055dc8-dc2f-4653-ba37-0e61776c9446" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07055dc8-dc2f-4653-ba37-0e61776c9446")) {                    Plotly.newPlot(                        "07055dc8-dc2f-4653-ba37-0e61776c9446",                        [{"marker":{"color":"#2ecc71"},"x":["Secrets","EAE Business School","Linkia FP","LightInTheBox","Wiber","Polsat News","Uredništvo iskreni.net","Vueling","[Not provided]","Piaggio"],"y":[12,10,6,6,5,5,5,4,2,2],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"ove ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dcd47ccf-94b9-4a20-baba-631b40c46d96" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dcd47ccf-94b9-4a20-baba-631b40c46d96")) {                    Plotly.newPlot(                        "dcd47ccf-94b9-4a20-baba-631b40c46d96",                        [{"marker":{"color":"#e74c3c"},"x":["Mute Labs","Vueling","Hyundai","Temu","American Express","Wine Moderation","OhMyBox","Nike","Endesa","mute-labs"],"y":[26,20,18,16,16,16,12,11,11,9],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidi ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="955663fc-63e0-4200-90bb-02f1c9022d9b" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("955663fc-63e0-4200-90bb-02f1c9022d9b")) {                    Plotly.newPlot(                        "955663fc-63e0-4200-90bb-02f1c9022d9b",                        [{"marker":{"color":"#3498db"},"x":["IONOS","Adobe","Movistar","Renault","heise","Radisson Hotels","Hyundai","AsiaTimes","Mute Labs","Asia Times"],"y":[21,13,11,10,10,10,9,9,8,7],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2 ...

# %%
mdf_filt = mdf[(mdf.Product.notna()) & (mdf.Product.apply(len) > 3)]
mdf_filt = mdf_filt[~mdf_filt.Product.isin(['Unknown', 'Not specified'])]

# Prepare data for each sentiment
positive_companies = mdf_filt[mdf_filt['Sentiment'] == 'Positive']['Product'].value_counts().head(10)
negative_companies = mdf_filt[mdf_filt['Sentiment'] == 'Negative']['Product'].value_counts().head(10)
neutral_companies = mdf_filt[mdf_filt['Sentiment'] == 'Neutral']['Product'].value_counts().head(10)

# Create three separate bar plots
import plotly.graph_objects as go

# Plot for Positive Sentiment
fig_positive = go.Figure()
fig_positive.add_trace(go.Bar(
   x=positive_companies.index,
   y=positive_companies.values,
   marker_color='#2ecc71'
))

fig_positive.update_layout(
   title='Top 10 Products in Positive Sentiment Articles',
   xaxis_title='Product',
   yaxis_title='Frequency',
   width=1000,
   height=600,
   plot_bgcolor='white',
   title_x=0.5,
   title_font_size=20,
   xaxis_tickangle=45
)
fig_positive.update_xaxes(showgrid=True, gridwidth=1, gridcolor='LightGray')
fig_positive.update_yaxes(showgrid=True, gridwidth=1, gridcolor='LightGray')
fig_positive.show()

# Plot for Negative Sentiment
fig_negative = go.Figure()
fig_negative.add_trace(go.Bar(
   x=negative_companies.index,
   y=negative_companies.values,
   marker_color='#e74c3c'
))

fig_negative.update_layout(
   title='Top 10 Products in Negative Sentiment Articles',
   xaxis_title='Product',
   yaxis_title='Frequency',
   width=1000,
   height=600,
   plot_bgcolor='white',
   title_x=0.5,
   title_font_size=20,
   xaxis_tickangle=45
)
fig_negative.update_xaxes(showgrid=True, gridwidth=1, gridcolor='LightGray')
fig_negative.update_yaxes(showgrid=True, gridwidth=1, gridcolor='LightGray')
fig_negative.show()

# Plot for Neutral Sentiment
fig_neutral = go.Figure()
fig_neutral.add_trace(go.Bar(
   x=neutral_companies.index,
   y=neutral_companies.values,
   marker_color='#3498db'
))

fig_neutral.update_layout(
   title='Top 10 Products in Neutral Sentiment Articles',
   xaxis_title='Product',
   yaxis_title='Frequency',
   width=1000,
   height=600,
   plot_bgcolor='white',
   title_x=0.5,
   title_font_size=20,
   xaxis_tickangle=45
)
fig_neutral.update_xaxes(showgrid=True, gridwidth=1, gridcolor='LightGray')
fig_neutral.update_yaxes(showgrid=True, gridwidth=1, gridcolor='LightGray')
fig_neutral.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="efbc3ba6-ec68-4d29-885d-2cf07f73dfc4" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("efbc3ba6-ec68-4d29-885d-2cf07f73dfc4")) {                    Plotly.newPlot(                        "efbc3ba6-ec68-4d29-885d-2cf07f73dfc4",                        [{"marker":{"color":"#2ecc71"},"x":["Restaurant","Event or talk","Political news","Car Rentals","Educational Programs","Educational Courses","Business Education","Services","Flight Services","News"],"y":[13,5,3,3,3,3,2,2,2,2],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="609f811b-2303-4758-b5a1-216e3e01e851" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("609f811b-2303-4758-b5a1-216e3e01e851")) {                    Plotly.newPlot(                        "609f811b-2303-4758-b5a1-216e3e01e851",                        [{"marker":{"color":"#e74c3c"},"x":["iPhone 15","Credit Card","Wine","Energy Services","Internet and Mobile Services","Banking Services","Concert","Political Campaign","Hyundai BAYON","Clothing"],"y":[16,14,13,12,11,11,11,9,8,8],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"patte ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2c3903e7-390a-4db8-ae4b-9806e3b184d8" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c3903e7-390a-4db8-ae4b-9806e3b184d8")) {                    Plotly.newPlot(                        "2c3903e7-390a-4db8-ae4b-9806e3b184d8",                        [{"marker":{"color":"#3498db"},"x":["Milk","News Article","Restaurant","Web Hosting Services","Art Exhibition","Investment Fund","Digital Services","Hotel Accommodation","Web Hosting","Coworking space"],"y":[6,5,5,5,4,4,4,4,4,3],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"patte ...

# %% [markdown]
# ## Analyze correlations

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from scipy.stats import chi2_contingency
import numpy as np
from collections import defaultdict

# Function to calculate Cramer's V
def cramers_v(confusion_matrix):
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    min_dim = min(confusion_matrix.shape) - 1
    return np.sqrt(chi2 / (n * min_dim))

# Function to analyze categorical relationships
def analyze_categorical_relationships(df, col1, col2):
    contingency = pd.crosstab(df[col1], df[col2])
    chi2, p_value, _, _ = chi2_contingency(contingency)
    cramer = cramers_v(contingency)
    return {
        'chi2': chi2,
        'p_value': p_value,
        'cramers_v': cramer
    }

# %%
# 1. Overall correlation analysis
categorical_cols = ['Product', 'Company', 'Coarse_Ad_Placement', 'Sentiment', 'Tone', 'Weekday']
correlation_results = defaultdict(dict)

for i in range(len(categorical_cols)):
    for j in range(i + 1, len(categorical_cols)):
        col1, col2 = categorical_cols[i], categorical_cols[j]
        results = analyze_categorical_relationships(mdf, col1, col2)
        correlation_results[col1][col2] = results

# Create heatmap of Cramer's V values
cramer_matrix = np.zeros((len(categorical_cols), len(categorical_cols)))
for i in range(len(categorical_cols)):
    for j in range(i + 1, len(categorical_cols)):
        col1, col2 = categorical_cols[i], categorical_cols[j]
        cramer_matrix[i, j] = correlation_results[col1][col2]['cramers_v']
        cramer_matrix[j, i] = cramer_matrix[i, j]

fig = go.Figure(data=go.Heatmap(
    z=cramer_matrix,
    x=categorical_cols,
    y=categorical_cols,
    colorscale='Viridis',
    text=np.round(cramer_matrix, 3),
    texttemplate='%{text}',
    textfont={"size": 10},
    hoverongaps=False
))

fig.update_layout(
    title='Cramer\'s V Correlation Heatmap',
    xaxis_title='Features',
    yaxis_title='Features'
)
fig.show()

# 2. Analysis for Tone and Sentiment
def analyze_category_distribution(df, target_col, analysis_cols=['Product', 'Company', 'Coarse_Ad_Placement']):
    results = []

    for analysis_col in analysis_cols:
        # Get top 10 categories for each tone/sentiment
        distribution = df.groupby([target_col, analysis_col]).size().reset_index(name='count')
        top_categories = (distribution.sort_values('count', ascending=False)
                         .groupby(target_col)
                         .head(10))

        # Create bar plot
        fig = px.bar(
            top_categories,
            x=analysis_col,
            y='count',
            color=target_col,
            title=f'Top Categories by {target_col}',
            barmode='group'
        )

        fig.update_layout(
            xaxis_tickangle=-45,
            xaxis_title=analysis_col,
            yaxis_title='Count'
        )
        fig.show()

        # Statistical testing
        contingency = pd.crosstab(df[target_col], df[analysis_col])
        chi2, p_value, _, _ = chi2_contingency(contingency)
        cramer = cramers_v(contingency)

        results.append({
            'analysis_col': analysis_col,
            'target_col': target_col,
            'chi2': chi2,
            'p_value': p_value,
            'cramers_v': cramer
        })

    return pd.DataFrame(results)

# Analyze for both Tone and Sentiment
tone_results = analyze_category_distribution(mdf, 'Tone')
sentiment_results = analyze_category_distribution(mdf, 'Sentiment')

# Print statistical results
print("\nTone Analysis Results:")
print(tone_results)
print("\nSentiment Analysis Results:")
print(sentiment_results)

# 3. Time-based analysis
weekday_distribution = mdf.groupby(['Weekday', 'Tone', 'Sentiment']).size().reset_index(name='count')

# Create weekday distribution plot
fig = px.bar(
    weekday_distribution,
    x='Weekday',
    y='count',
    color='Tone',
    facet_col='Sentiment',
    title='Distribution of Tone and Sentiment by Weekday',
    barmode='group'
)

fig.update_layout(
    xaxis_tickangle=-45
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e490d920-57e1-47a9-9c5a-160722817d7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e490d920-57e1-47a9-9c5a-160722817d7d")) {                    Plotly.newPlot(                        "e490d920-57e1-47a9-9c5a-160722817d7d",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"hoverongaps":false,"text":[[0.0,0.885,0.867,0.885,0.861,0.878],[0.885,0.0,0.647,0.766,0.702,0.743],[0.867,0.647,0.0,0.112,0.2,0.096],[0.885,0.766,0.112,0.0,0.863,0.311],[0.861,0.702,0.2,0.863,0.0,0.44],[0.878,0.743,0.096,0.311,0.44,0.0]],"textfont":{"size":10},"texttemplate":"%{text}","x":["Product","Company","Coarse_Ad_Placement","Sentiment","Tone","Weekday"],"y":["Product","Company","Coarse_Ad_Placement","Sentiment","Tone","Weekday"],"z":[[0.0,0.8854050179406061,0.8670806697085174,0.8852752632560457,0.8606797896557861,0.8784136708976059],[0.8854050179406061,0.0,0.6469826766993128,0.7663059408662483,0.7017628715871675,0.7433429202860031],[0.8670806697085174,0.6469826766993128,0.0,0.11218362991732536,0.20006060809308093,0.09578919629989453],[0.8852752632560457,0.7663059408662483,0.11218362991732536,0.0,0.8632552800051649,0.3114155907638365],[0.8606797896557861,0.7017628715871675,0.20006060809308093,0.8632552800051649,0.0,0.4404508018097748],[0.8784136708976059,0.7433429202860031,0.09578919629989453,0.3114155907638365,0.4404508018097748,0.0]],"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0, ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4c33c9e6-d231-4868-a921-04bfb94328b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c33c9e6-d231-4868-a921-04bfb94328b0")) {                    Plotly.newPlot(                        "4c33c9e6-d231-4868-a921-04bfb94328b0",                        [{"alignmentgroup":"True","hovertemplate":"Tone=Encouraging\u003cbr\u003eProduct=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Encouraging","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Encouraging","offsetgroup":"Encouraging","orientation":"v","showlegend":true,"textposition":"auto","x":["Restaurant","Event or talk","Educational Courses","Car Rentals","Educational Programs","Clothing","App registration","Restaurant services","Scooters","Tires"],"xaxis":"x","y":[13,5,3,3,2,2,2,2,2,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Critical\u003cbr\u003eProduct=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Critical","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Critical","offsetgroup":"Critical","orientation":"v","showlegend":true,"textposition":"auto","x":["Wine","","Political campaign","Car","Banking Services","Wine Moderation","Storage Units","Footwear","News Article","Subscription service"],"xaxis":"x","y":[13,13,5,5,5,3,3,3,3,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Descriptive\u003cbr\u003eProduct=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Descriptive","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Descriptive","offsetgroup":"Descriptive","orientation":"v","showlegend":true,"textposition":"auto","x":["iPhone 15","Credit Card","Car","","Milk","Insurance Services","Book","Swimwear","Gaming Laptop","Shoes"],"xaxis":"x","y":[13,10,9,9,6,5,5,5,4,4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Informative\u003cbr\u003eProduct=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Informative","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Informative","offsetgroup":"Informative","orientation":"v","showlegend":true,"textposition":"auto","x":["","News Article","Restaurant","Car","Art Exhibition","Digital Services","Web Hosting Services","Political news","iPhone 15","Real estate app"],"xaxis":"x","y":[11,5,5,4,4,4,4,3,3,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Fear-mongering\u003cbr\u003eProduct=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fear-mongering","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Fear-mongering","offsetgroup":"Fear-mongering","orientation":"v","showlegend":true,"textposition":"auto","x":["","Diet program","Civil Petition","Soundproof Meeting Cabin","Political Campaign","Passive Cases","Funeral Services","Banking Services","Hotel reservation","Hyundai Cars"],"xaxis":"x","y":[8,3,3,2,2,2,2,2,1,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Investigative\u003cbr\u003eProduct=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Investigative","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Investigative","offsetgroup":"Investigative","orientation":"v","showlegend":true,"textposition":"auto","x":["Hyundai BAYON","Job Opening","Cured Ham","Samsung OLED","SUVs by Kia","Pasta Dish","LG QNED","Hyundai i30 Hybrid","Fast Food","Contact management software"],"xaxis":"x","y":[7,4,2,1,1,1,1,1,1,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Alarming\u003cbr\u003eProduct=%{x}\u003cbr\u003ecount=%{y} ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="93dbf2a5-e58c-4137-93b0-d5ca280252ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93dbf2a5-e58c-4137-93b0-d5ca280252ce")) {                    Plotly.newPlot(                        "93dbf2a5-e58c-4137-93b0-d5ca280252ce",                        [{"alignmentgroup":"True","hovertemplate":"Tone=Informative\u003cbr\u003eCompany=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Informative","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Informative","offsetgroup":"Informative","orientation":"v","showlegend":true,"textposition":"auto","x":["","Unknown","IONOS","Not specified","Adobe","heise","EAE Business School","AsiaTimes","Renault","Movistar"],"xaxis":"x","y":[41,21,17,16,11,10,10,9,9,7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Descriptive\u003cbr\u003eCompany=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Descriptive","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Descriptive","offsetgroup":"Descriptive","orientation":"v","showlegend":true,"textposition":"auto","x":["Unknown","","Mute Labs","American Express","Not specified","Carrefour","Hyundai","Acer","Movistar","Vueling"],"xaxis":"x","y":[34,25,20,12,11,10,10,9,9,8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Critical\u003cbr\u003eCompany=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Critical","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Critical","offsetgroup":"Critical","orientation":"v","showlegend":true,"textposition":"auto","x":["","Wine Moderation","Unknown","OhMyBox","heise","Ciudadanos","Temu","heise online","Culligan","Not specified"],"xaxis":"x","y":[26,16,13,8,7,7,6,6,6,5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Accusatory\u003cbr\u003eCompany=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accusatory","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Accusatory","offsetgroup":"Accusatory","orientation":"v","showlegend":true,"textposition":"auto","x":["O2","Endesa","Semrush","SEMrush","","Sorolla Expo Barcelona","TENA","Unknown","Informer","Not specified"],"xaxis":"x","y":[12,6,3,3,2,2,2,2,2,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Encouraging\u003cbr\u003eCompany=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Encouraging","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Encouraging","offsetgroup":"Encouraging","orientation":"v","showlegend":true,"textposition":"auto","x":["Secrets","Linkia FP","LightInTheBox","","Uredništvo iskreni.net","Wiber","Not specified","Market of Goods","Fundación Telefónica","Michelin"],"xaxis":"x","y":[12,6,6,6,5,5,4,2,2,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Alarmist\u003cbr\u003eCompany=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Alarmist","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Alarmist","offsetgroup":"Alarmist","orientation":"v","showlegend":true,"textposition":"auto","x":["","O2","Vueling","Unknown","Nike","Michelin","Octopus Energy","max","Not specified","AsiaTimes"],"xaxis":"x","y":[11,11,8,8,5,5,4,4,3,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Alarming\u003cbr\u003eCompany=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Alarming","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Alarming","offsetgroup":"Alarming","orientation":"v","showlegend":true,"textposition":"auto","x ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="105aea5d-6f6b-4dd2-9216-2b937692740e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("105aea5d-6f6b-4dd2-9216-2b937692740e")) {                    Plotly.newPlot(                        "105aea5d-6f6b-4dd2-9216-2b937692740e",                        [{"alignmentgroup":"True","hovertemplate":"Tone=Descriptive\u003cbr\u003eCoarse_Ad_Placement=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Descriptive","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Descriptive","offsetgroup":"Descriptive","orientation":"v","showlegend":true,"textposition":"auto","x":["sidebar","bottom section","inline","top section","banner","main section","middle section","other","overlay"],"xaxis":"x","y":[221,83,55,39,28,15,8,3,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Informative\u003cbr\u003eCoarse_Ad_Placement=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Informative","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Informative","offsetgroup":"Informative","orientation":"v","showlegend":true,"textposition":"auto","x":["sidebar","bottom section","top section","inline","banner","main section","middle section","other","popup"],"xaxis":"x","y":[175,90,59,42,30,19,4,1,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Critical\u003cbr\u003eCoarse_Ad_Placement=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Critical","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Critical","offsetgroup":"Critical","orientation":"v","showlegend":true,"textposition":"auto","x":["sidebar","bottom section","inline","top section","banner","main section","other section","other","middle section","popup"],"xaxis":"x","y":[140,32,27,25,18,5,3,2,2,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Alarmist\u003cbr\u003eCoarse_Ad_Placement=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Alarmist","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Alarmist","offsetgroup":"Alarmist","orientation":"v","showlegend":true,"textposition":"auto","x":["sidebar","bottom section","inline","banner","top section","main section","overlay","middle section"],"xaxis":"x","y":[69,21,16,13,12,2,1,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Encouraging\u003cbr\u003eCoarse_Ad_Placement=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Encouraging","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Encouraging","offsetgroup":"Encouraging","orientation":"v","showlegend":true,"textposition":"auto","x":["sidebar","bottom section","inline","top section","banner","middle section","main section","overlay"],"xaxis":"x","y":[45,22,15,10,7,2,2,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Fear-mongering\u003cbr\u003eCoarse_Ad_Placement=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fear-mongering","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Fear-mongering","offsetgroup":"Fear-mongering","orientation":"v","showlegend":true,"textposition":"auto","x":["sidebar","bottom section","banner","top section","inline","middle section","main section"],"xaxis":"x","y":[31,7,6,6,4,2,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Accusatory\u003cbr\u003eCoarse_Ad_Placement=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accusatory","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Accusatory","offsetgroup":"Accusatory","or ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="749eccc5-af6d-45c7-bf4a-f95de92e363d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("749eccc5-af6d-45c7-bf4a-f95de92e363d")) {                    Plotly.newPlot(                        "749eccc5-af6d-45c7-bf4a-f95de92e363d",                        [{"alignmentgroup":"True","hovertemplate":"Sentiment=Negative\u003cbr\u003eProduct=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Negative","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Negative","offsetgroup":"Negative","orientation":"v","showlegend":true,"textposition":"auto","x":["","iPhone 15","Credit Card","Wine","Energy Services","Banking Services","Car","Concert","Internet and Mobile Services","Political Campaign"],"xaxis":"x","y":[33,16,14,13,12,11,11,11,11,9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sentiment=Positive\u003cbr\u003eProduct=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Positive","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Positive","offsetgroup":"Positive","orientation":"v","showlegend":true,"textposition":"auto","x":["Restaurant","Event or talk","Educational Programs","","Educational Courses","Car Rentals","Political news","Tires","News","Flight Services"],"xaxis":"x","y":[13,5,3,3,3,3,3,2,2,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sentiment=Neutral\u003cbr\u003eProduct=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Neutral","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Neutral","offsetgroup":"Neutral","orientation":"v","showlegend":true,"textposition":"auto","x":["","Car","Milk","Restaurant","Web Hosting Services","News Article","Digital Services","Hotel Accommodation","Web Hosting","Art Exhibition"],"xaxis":"x","y":[13,7,6,5,5,5,4,4,4,4],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="54511aee-95de-45a3-93ef-b4f8c23dd069" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54511aee-95de-45a3-93ef-b4f8c23dd069")) {                    Plotly.newPlot(                        "54511aee-95de-45a3-93ef-b4f8c23dd069",                        [{"alignmentgroup":"True","hovertemplate":"Sentiment=Negative\u003cbr\u003eCompany=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Negative","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Negative","offsetgroup":"Negative","orientation":"v","showlegend":true,"textposition":"auto","x":["","Unknown","Not specified","O2","Mute Labs","Vueling","Hyundai","Temu","Wine Moderation","American Express"],"xaxis":"x","y":[97,75,38,34,26,20,18,16,16,16],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sentiment=Neutral\u003cbr\u003eCompany=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Neutral","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Neutral","offsetgroup":"Neutral","orientation":"v","showlegend":true,"textposition":"auto","x":["","Unknown","IONOS","Not specified","Adobe","Movistar","Renault","Radisson Hotels","heise","Hyundai"],"xaxis":"x","y":[46,28,21,20,13,11,10,10,10,9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sentiment=Positive\u003cbr\u003eCompany=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Positive","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Positive","offsetgroup":"Positive","orientation":"v","showlegend":true,"textposition":"auto","x":["Secrets","","EAE Business School","LightInTheBox","Linkia FP","Not specified","Uredništvo iskreni.net","Wiber","Polsat News","Unknown"],"xaxis":"x","y":[12,11,10,6,6,5,5,5,5,4],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="81146d6d-9a51-432e-abaa-7559353312c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81146d6d-9a51-432e-abaa-7559353312c8")) {                    Plotly.newPlot(                        "81146d6d-9a51-432e-abaa-7559353312c8",                        [{"alignmentgroup":"True","hovertemplate":"Sentiment=Negative\u003cbr\u003eCoarse_Ad_Placement=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Negative","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Negative","offsetgroup":"Negative","orientation":"v","showlegend":true,"textposition":"auto","x":["sidebar","bottom section","inline","top section","banner","main section","middle section","other","overlay","other section"],"xaxis":"x","y":[592,191,131,93,76,25,23,5,4,4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sentiment=Neutral\u003cbr\u003eCoarse_Ad_Placement=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Neutral","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Neutral","offsetgroup":"Neutral","orientation":"v","showlegend":true,"textposition":"auto","x":["sidebar","bottom section","top section","inline","banner","main section","middle section","other","overlay","popup"],"xaxis":"x","y":[238,111,72,55,38,19,5,2,2,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sentiment=Positive\u003cbr\u003eCoarse_Ad_Placement=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Positive","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Positive","offsetgroup":"Positive","orientation":"v","showlegend":true,"textposition":"auto","x":["sidebar","bottom section","inline","top section","main section","banner","middle section","overlay"],"xaxis":"x","y":[57,32,17,16,12,11,3,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"], ...
# Tone Analysis Results:
#           analysis_col target_col          chi2        p_value  cramers_v
# 0              Product       Tone  40846.041276   2.913439e-68   0.860680
# 1              Company       Tone  27154.857995  2.837196e-303   0.701763
# 2  Coarse_Ad_Placement       Tone    735.645658   1.514095e-38   0.200061
#
# Sentiment Analysis Results:
#           analysis_col target_col         chi2       p_value  cramers_v
# 0              Product  Sentiment  2880.926384  2.636512e-11   0.885275
# 1              Company  Sentiment  2158.638346  9.496568e-50   0.766306
# 2  Coarse_Ad_Placement  Sentiment    46.263073  7.416374e-04   0.112184
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="39f9b8b3-619a-48d3-bd35-2cc39f78f5f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("39f9b8b3-619a-48d3-bd35-2cc39f78f5f2")) {                    Plotly.newPlot(                        "39f9b8b3-619a-48d3-bd35-2cc39f78f5f2",                        [{"alignmentgroup":"True","hovertemplate":"Tone=Alarmist\u003cbr\u003eSentiment=Negative\u003cbr\u003eWeekday=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Alarmist","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Alarmist","offsetgroup":"Alarmist","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday","Saturday","Sunday","Tuesday","Wednesday"],"xaxis":"x","y":[30,42,19,35,9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Celebratory\u003cbr\u003eSentiment=Positive\u003cbr\u003eWeekday=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Celebratory","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Celebratory","offsetgroup":"Celebratory","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday"],"xaxis":"x2","y":[6],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Critical\u003cbr\u003eSentiment=Negative\u003cbr\u003eWeekday=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Critical","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Critical","offsetgroup":"Critical","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x","y":[79,16,10,7,115,24],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Descriptive\u003cbr\u003eSentiment=Negative\u003cbr\u003eWeekday=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Descriptive","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Descriptive","offsetgroup":"Descriptive","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x","y":[57,20,57,24,65,45,63],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Descriptive\u003cbr\u003eSentiment=Positive\u003cbr\u003eWeekday=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Descriptive","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Descriptive","offsetgroup":"Descriptive","orientation":"v","showlegend":false,"textposition":"auto","x":["Sunday"],"xaxis":"x2","y":[6],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Descriptive\u003cbr\u003eSentiment=Neutral\u003cbr\u003eWeekday=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Descriptive","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Descriptive","offsetgroup":"Descriptive","orientation":"v","showlegend":false,"textposition":"auto","x":["Friday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x3","y":[21,19,56,20,1],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Informative\u003cbr\u003eSentiment=Negative\u003cbr\u003eWeekday=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Informative","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Informative","offsetgroup":"Informative","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[16],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tone=Informative\u003cbr\u003eSentiment=Positive\u003cbr\u003eWeekday=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","l ...
